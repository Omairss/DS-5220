# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
from sklearn import linear_model
import scipy.stats
from sklearn.metrics import accuracy_score
np.set_printoptions(suppress=True)

# %%
def genData(numPoints):
    x = np.zeros(shape=(numPoints, 3))
    y = np.zeros(shape=numPoints)
    
    x[:,0] = 1
    #x[:,1] = [i for i in range(numPoints)]
    x[:,1] = np.random.uniform(0, 3, size = numPoints)
    x[:,2] = np.random.uniform(0, 3, size = numPoints)


    
    for i in range(0, numPoints): y[i] =  1/(1 + np.exp( - (-3 + (x[i][1]) + (x[i][2]))))
    #for i in range(0, numPoints): y[i] =  1/(1 + np.exp( - (-3 + (x[i][1]))))

    
    y = np.array([1 if i > 0.5 else 0 for i in y])
    return x, y

# %%
x,y = (genData(50))
#y_temp = np.array([1 if i > 0.5 else 0 for i in y])

# %%
plt.scatter(x[:,1], y)

# %%
def gradientDescent(x, y, theta, alpha, m, numIterations):
    
    xTrans = x.transpose()
    
    for i in range(0, numIterations):
        
        loss = (1 / (1 + np.exp(-(1 + (np.dot(x, theta)))))) - y
        
        #print (np.mean(loss))
        
        #gradient = np.dot(xTrans,  np.dot(x, theta) - y) / m #Partial derivative   
        gradient = np.dot(xTrans, loss) / m
        theta = theta - alpha * gradient
        
    
    return theta

# %%
m, n = np.shape(x) 

theta = gradientDescent(x,y, np.ones(n), 1, m, 70000)

# %%
theta
# Out:
# array([-64.06329332,  21.21244436,  21.13831545])

# %%
hypothesis = lambda x: 1 / (1 + (np.exp(-(x * theta[1] + x * theta[2]+ theta[0]))))

plt.plot([i for i in range(0,4)],[hypothesis(i) for i in range(0,4)])

plt.scatter([i[1] for i in x], y, s=50, alpha = 0.5)
plt.show()

# %% [markdown]
# ## Decision boundaries for X[1] vs X[2] and X[1] vs X[0] respectively for Batch GD

# %%
d_boundary_plot = lambda x: x*theta[1] + x*theta[2] + theta[0]
plt.plot([i for i in range(1,3)],[d_boundary_plot(i) for i in range(1,3)])

#plt.scatter([i[1] for i in x], [i[2] for i in x], s=50, alpha = 0.5)

for label,marker,color in zip(range(0,2),('^', 's'),('blue', 'red')):

        plt.scatter(x=x[:,1].real[y == label],
                y=x[:,2].real[y == label],
                marker=marker,
                color=color,
                alpha=0.5
                )

# %%
d_boundary_plot = lambda x: x*theta[1] + x*theta[2] + theta[0]
plt.plot([i for i in range(1,3)],[d_boundary_plot(i) for i in range(1,3)])

#plt.scatter([i[1] for i in x], [i[2] for i in x], s=50, alpha = 0.5)

for label,marker,color in zip(range(0,2),('^', 's'),('blue', 'red')):

        plt.scatter(x=x[:,1].real[y == label],
                y=x[:,0].real[y == label],
                marker=marker,
                color=color,
                alpha=0.5
                )

# %%
def gradientDescentSto(x, y, theta, alpha, m, numIterations, delta=2, conv=0.00000001):

    xTrans = x.transpose()
    count = 0
    theta_prev = theta + delta + 1
    
    while (count < numIterations):
            
            count += 1

            for i in range(m):

                hypothesis = x[i][0]*theta[0] + x[i][1]*theta[1] + x[i][2]*theta[2]
                
                loss = 1/(1 + np.exp(- hypothesis)) - y[i]
                
                #loss = hypothesis - y[i]

                gradient1 = x[i][0] * loss
                gradient0 = x[i][1] * loss

                theta_prev = theta
                theta[1] = theta[1] - alpha * gradient0
                theta[0] = theta[0] - alpha * gradient1
                                
        
    return theta

# %%
theta = gradientDescentSto(x, y, theta, 0.08, m, 10000)

# %%
theta
# Out:
# array([-76.07758459,  25.30392253,  25.53271225])

# %%
hypothesis = lambda x: 1 / (1 + (np.exp(-(x * theta[1] + x * theta[2] + theta[0]))))

plt.plot([i for i in range(-10,10)],[hypothesis(i) for i in range(-10,10)])
plt.scatter([i[2] for i in x], y, s=10)
plt.show()

# %% [markdown]
# ## Decision boundaries for X[1] vs X[2] and X[1] vs X[0] respectively for Stochastic GD

# %%
d_boundary_plot = lambda x: x*theta[1] + x*theta[2] + theta[0]
plt.plot([i for i in range(1,3)],[d_boundary_plot(i) for i in range(1,3)])

#plt.scatter([i[1] for i in x], [i[2] for i in x], s=50, alpha = 0.5)

for label,marker,color in zip(range(0,2),('^', 's'),('blue', 'red')):

        plt.scatter(x=x[:,1].real[y == label],
                y=x[:,2].real[y == label],
                marker=marker,
                color=color,
                alpha=0.5
                )

# %%
d_boundary_plot = lambda x: x*theta[1] + x*theta[2] + theta[0]
plt.plot([i for i in range(1,3)],[d_boundary_plot(i) for i in range(1,3)])

#plt.scatter([i[1] for i in x], [i[2] for i in x], s=50, alpha = 0.5)

for label,marker,color in zip(range(0,2),('^', 's'),('blue', 'red')):

        plt.scatter(x=x[:,1].real[y == label],
                y=x[:,0].real[y == label],
                marker=marker,
                color=color,
                alpha=0.5
                )

# %%
d_boundary = lambda x0,x1: x0*theta[1] + x1*theta[2] + theta[0]
y_hat = [1 if i > 0 else 0 for i in np.sum(np.array([d_boundary(i) for i in x]),axis=1)]

# %%
accuracy_score(y, y_hat)
# Out:
# 0.88

# %% [markdown]
# ## Linear discriminant analysis

# %%
x_old = x
x = x[:, 1:]

# %%
mean_vectors = []
y_temp = np.array([1 if i > 0.5 else 0 for i in y])

for i in range(0,2):    
    mean_vectors.append(np.mean(x[y_temp==i], axis = 0))
    print('Mean Vector class %s: %s\n' %(i, mean_vectors[i]))
# Out:
# Mean Vector class 0: [0.88690415 0.96114626]
#
# Mean Vector class 1: [2.05286584 2.01362188]

# %%
S_W = np.zeros((2,2))

for cl,mv in zip(range(0,2), mean_vectors):
    
    class_sc_mat = np.zeros((2,2))                  # scatter matrix for every class    
    for row in x[y_temp == cl]: 
        row, mv = row.reshape(2,1), mv.reshape(2,1) # make column vectors
        
        class_sc_mat += (row-mv).dot((row-mv).T)
    
    S_W += class_sc_mat                             # sum class scatter matrices

print('within-class Scatter Matrix:\n', S_W)
# Out:
# within-class Scatter Matrix:
#  [[ 25.44815673 -11.48291506]
#  [-11.48291506  26.66996612]]

# %%
overall_mean = np.mean(x, axis=0)

S_B = np.zeros((2,2))

for i,mean_vec in enumerate(mean_vectors):  
    n = x[y_temp==i+1,:].shape[0]
    mean_vec = mean_vec.reshape(2,1) # make column vector
    overall_mean = overall_mean.reshape(2,1) # make column vector
    S_B += n * (mean_vec - overall_mean).dot((mean_vec - overall_mean).T)

print('between-class Scatter Matrix:\n', S_B)
# Out:
# between-class Scatter Matrix:
#  [[9.55759443 8.62732904]
#  [8.62732904 7.78760878]]

# %%
eig_vals, eig_vecs = np.linalg.eig(np.linalg.inv(S_W).dot(S_B))

for i in range(len(eig_vals)):
    eigvec_sc = eig_vecs[:,i].reshape(2,1)   
    print('\nEigenvector {}: \n{}'.format(i+1, eigvec_sc.real))
    print('Eigenvalue {:}: {:.2e}'.format(i+1, eig_vals[i].real))
# Out:
# Eigenvector 1:
# [[0.73215943]
#  [0.6811333 ]]
# Eigenvalue 1: 1.19e+00
#
# Eigenvector 2:
# [[-0.67005795]
#  [ 0.74230879]]
# Eigenvalue 2: 0.00e+00

# %%
for i in range(len(eig_vals)):
    eigv = eig_vecs[:,i].reshape(2,1)
    np.testing.assert_array_almost_equal(np.linalg.inv(S_W).dot(S_B).dot(eigv),
                                         eig_vals[i] * eigv,
                                         decimal=6, err_msg='', verbose=True)
print('ok')
# Out:
# ok

# %%
# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs = sorted(eig_pairs, key=lambda k: k[0], reverse=True)

# Visually confirm that the list is correctly sorted by decreasing eigenvalues

print('Eigenvalues in decreasing order:\n')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in decreasing order:
#
# 1.190859944108663
# 0.0

# %%
print('Variance explained:\n')
eigv_sum = sum(eig_vals)
for i,j in enumerate(eig_pairs):
    print('eigenvalue {0:}: {1:.2%}'.format(i+1, (j[0]/eigv_sum).real))
# Out:
# Variance explained:
#
# eigenvalue 1: 100.00%
# eigenvalue 2: 0.00%

# %%
W = eig_pairs[0][1].reshape(2,1)
print('Matrix W:\n', W.real)
# Out:
# Matrix W:
#  [[0.73215943]
#  [0.6811333 ]]

# %%
np.hstack((eig_pairs[0][1].reshape(2,1), eig_pairs[1][1].reshape(2,1)))[0]
# Out:
# array([ 0.73215943, -0.67005795])

# %%
x_lda = x.dot(W)
assert x_lda.shape == (50,1), "The matrix is not 150x2 dimensional."

# %%
from matplotlib import pyplot as plt

def plot_step_lda(feature):

    ax = plt.subplot(111)
    for label,marker,color in zip(
        range(0,2),('^', 's', 'o'),('blue', 'red', 'green')):

        plt.scatter(x=x[:,feature].real[y_temp == label],
                y=x_lda[:,0].real[y_temp == label],
                marker=marker,
                color=color,
                alpha=0.5
                )

    plt.xlabel('Actual X0')
    plt.ylabel('LDA X')

    leg = plt.legend(loc='upper right', fancybox=True)
    leg.get_frame().set_alpha(0.5)
    plt.title('X against LDA X')

    # hide axis ticks
    plt.tick_params(axis="both", which="both", bottom="off", top="off",  
            labelbottom="on", left="off", right="off", labelleft="on")

    # remove axis spines
    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)    

    
    plt.grid()
    plt.tight_layout
    plt.show()

plot_step_lda(0)
plot_step_lda(1)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## The above plot shows the relationship between actual X and LDA transformed X. Both X0 and X1 are shown to be linearly seperated at X ~ 2.0

# %%
def plot_step_lda():

    
    ax = plt.subplot(111)
    for label,marker,color in zip(
        range(0,2),('^', 's', 'o'),('blue', 'red', 'green')):

        plt.scatter(x=x_lda[:,0].real[y == label],
                y=y.real[y == label],
                marker=marker,
                color=color,
                alpha=0.5
                )

    plt.xlabel('LDA X')
    plt.ylabel('Actual Y')

    leg = plt.legend(loc='upper right', fancybox=True)
    leg.get_frame().set_alpha(0.5)
    plt.title('LDA: Actual Y against LDA X')

    # hide axis ticks
    plt.tick_params(axis="both", which="both", bottom="off", top="off",  
            labelbottom="on", left="off", right="off", labelleft="on")

    # remove axis spines
    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)    

    plt.grid()
    plt.tight_layout
    plt.show()

plot_step_lda()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## There is a clean seperation once LDA is applied to X

# %%
y_hat = [1 if i>=2 else 0 for i in x_lda]

# %%
accuracy_score(y, y_hat)
# Out:
# 0.96

# %% [markdown]
# ## Histograms of the three methods

# %%
accuracies_gd = []

for run in range(50):

    x,y = (genData(50))
    m, n = np.shape(x) 
    theta = gradientDescent(x,y, np.ones(n), 1, m, 70000)

    d_boundary = lambda x: x[0]*theta[1] + x[1]*theta[2] + x[2]*theta[0]


    y_hat = [0 if i > 0 else 1 for i in [d_boundary(i) for i in x]]
    accuracies_gd.append(accuracy_score(y, y_hat))
    
plt.hist(np.array(accuracies_gd), label = 'GD')
# Out:
# (array([ 4.,  1.,  7.,  8.,  6., 11.,  6.,  5.,  1.,  1.]),
#  array([0.5  , 0.528, 0.556, 0.584, 0.612, 0.64 , 0.668, 0.696, 0.724,
#         0.752, 0.78 ]),
#  <a list of 10 Patch objects>)

# %%
accuracies_sto = []

for run in range(10):
    
    print (run)
    x,y = (genData(50))
    m, n = np.shape(x) 
    theta = gradientDescentSto(x,y, np.ones(n), 1, m, 70000)

    d_boundary = lambda x: x[0]*theta[1] + x[1]*theta[2] + x[2]*theta[0]


    y_hat = [0 if i > 0 else 1 for i in [d_boundary(i) for i in x]]
    accuracies_sto.append(accuracy_score(y, y_hat))
    
plt.hist(np.array(accuracies_sto), label = 'GD')
# Out:
# 0
# 1
# 2
# 3
# 4
# (array([1., 1., 0., 0., 0., 0., 0., 1., 1., 1.]),
#  array([0.6  , 0.614, 0.628, 0.642, 0.656, 0.67 , 0.684, 0.698, 0.712,
#         0.726, 0.74 ]),
#  <a list of 10 Patch objects>)

# %%
accuracies_lda = []

for run in range(200):
    x,y = (genData(50))
    x = x[:, 1:]

    mean_vectors = []
    y_temp = np.array([1 if i > 0.5 else 0 for i in y])

    for i in range(0,2):    
        mean_vectors.append(np.mean(x[y_temp==i], axis = 0))

    S_W = np.zeros((2,2))

    for cl,mv in zip(range(0,2), mean_vectors):

        class_sc_mat = np.zeros((2,2))                  # scatter matrix for every class    
        for row in x[y_temp == cl]: 
            row, mv = row.reshape(2,1), mv.reshape(2,1) # make column vectors

            class_sc_mat += (row-mv).dot((row-mv).T)

        S_W += class_sc_mat                             # sum class scatter matrices

    overall_mean = np.mean(x, axis=0)

    S_B = np.zeros((2,2))

    for i,mean_vec in enumerate(mean_vectors):  
        n = x[y_temp==i+1,:].shape[0]
        mean_vec = mean_vec.reshape(2,1) # make column vector
        overall_mean = overall_mean.reshape(2,1) # make column vector
        S_B += n * (mean_vec - overall_mean).dot((mean_vec - overall_mean).T)

    eig_vals, eig_vecs = np.linalg.eig(np.linalg.inv(S_W).dot(S_B))

    for i in range(len(eig_vals)):
        eigvec_sc = eig_vecs[:,i].reshape(2,1) 

    # Make a list of (eigenvalue, eigenvector) tuples
    eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

    # Sort the (eigenvalue, eigenvector) tuples from high to low
    eig_pairs = sorted(eig_pairs, key=lambda k: k[0], reverse=True)
    eigv_sum = sum(eig_vals)
    W = eig_pairs[0][1].reshape(2,1)
    np.hstack((eig_pairs[0][1].reshape(2,1), eig_pairs[1][1].reshape(2,1)))[0]

    x_lda = x.dot(W)
    assert x_lda.shape == (50,1), "The matrix is not 150x2 dimensional."

    y_hat = [1 if i>=2 else 0 for i in x_lda]
    accuracies_lda.append(accuracy_score(y, y_hat))

plt.hist(np.array(accuracies_lda), label = 'GD')
# Out:
# (array([12., 26., 27., 16.,  8.,  0.,  0.,  0., 23., 88.]),
#  array([0.36 , 0.424, 0.488, 0.552, 0.616, 0.68 , 0.744, 0.808, 0.872,
#         0.936, 1.   ]),
#  <a list of 10 Patch objects>)
